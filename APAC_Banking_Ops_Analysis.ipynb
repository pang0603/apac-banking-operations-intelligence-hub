# %% [markdown]
# # APAC Banking Operations Intelligence Hub
# ### Automated Process Analysis & STP Performance Optimization Report
# **Author:** Chelsea Pang Kiat Si <br>
# **Target Role:** Digital Transformation Business Analyst (OCBC Alignment)

# %% [markdown]
# ## 1. Global Metric Baseline: Straight-Through Processing (STP) Rate
# The baseline health metric calculates core automation capacity.

# %%
# SQL Query to verify base operational health
print(df_stp)
# Out:
#  total_transactions  successful_stp_txns  overall_stp_rate_pct
#                2000                 1779                 88.95

# %% [markdown]
# ## 2. Regional Volume Share & STP Divergence Analysis
# This section isolates transaction volume distribution and processing efficiency across our four operational hubs.

# %%
# Plotting regional bottlenecks
print(df_regional)
# Out:
# region  transaction_volume  regional_volume_share_pct  regional_stp_rate_pct
#     SG                 756                       37.8                  92.20
#     MY                 546                       27.3                  89.19
#     TH                 408                       20.4                  85.78
#     ID                 290                       14.5                  84.48

# %% [markdown]
# ## 3. Processing Channel Ingestion Vulnerabilities
# Isolating where legacy system handshakes create processing dropouts.

# %%
# Isolate leakage channels
print(df_channel)
# Out:
#                 channel  total_txns  total_failures  failure_rate_pct
# SWIFT/Corporate Gateway         204              37             18.14
#                  Branch         113              17             15.04
#        Internet Banking         620              73             11.77
#                     ATM         192              19              9.90
#              Mobile App         871              75              8.61
